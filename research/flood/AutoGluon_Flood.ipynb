# %% [markdown]
# # Project: Kaggle Flood Competition

# %% [markdown]
# This project utilizes the AutoML framework AutoGluon to compete in the Kaggle competition [Regression with a Flood Prediction Dataset](https://www.kaggle.com/competitions/playground-series-s4e5/overview). Below are the frameworks and platforms used for this project.
#
# - AutoGluon - A AutoML framework for prototyping ML ensemble models.
# - SageMaker Studio - Jupyter Lab and Code Editor was used to developer this notebook and the accompanying scripts.
# - GitHub - The code repository used for this project.
# - SageMaker Sklearn Docker Image - A prebuilt Amazon SageMaker container used to run AutoGluon model training jobs on AWS spot instances.
#
# Results: Using SageMaker training job reduced training costs by almost 50%. This is a regression task and the performance metric is $R^2$. My model's score was 0.86884. The top score was 0.86905.

# %% [markdown]
# # Update Python Packages

# %% [markdown]
# The code below installs the latest version of AutoGluon. SageMaker uses Conda for package management.

# %%
# !conda list autogluon
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# autogluon                 0.8.2              pyhd8ed1ab_4    conda-forge
# autogluon.common          0.8.2              pyhd8ed1ab_4    conda-forge
# autogluon.core            0.8.2           light_py310h2d11d36_6    conda-forge
# autogluon.features        0.8.2              pyhd8ed1ab_3    conda-forge
# autogluon.multimodal      0.8.2              pyha770c72_5    conda-forge
# autogluon.tabular         0.8.2              pyha770c72_4    conda-forge
# autogluon.timeseries      0.8.2              pyhd8ed1ab_4    conda-forge

# %%
# !pip uninstall -y autogluon
# !pip uninstall -y autogluon.multimodal
# !pip uninstall -y autogluon.tabular
# !pip uninstall -y autogluon.timeseries 
# !pip install -qU bokeh==2.0.1 --progress-bar off
# !pip install -qU autogluon.tabular[lightgbm,catboost,xgboost] --progress-bar off
# Out:
# Found existing installation: autogluon 0.8.2
# Uninstalling autogluon-0.8.2:
#   Successfully uninstalled autogluon-0.8.2
# Found existing installation: autogluon.multimodal 0.8.2
# Uninstalling autogluon.multimodal-0.8.2:
#   Successfully uninstalled autogluon.multimodal-0.8.2
# Found existing installation: autogluon.tabular 0.8.2
# Uninstalling autogluon.tabular-0.8.2:
#   Successfully uninstalled autogluon.tabular-0.8.2
# Found existing installation: autogluon.timeseries 0.8.2
# Uninstalling autogluon.timeseries-0.8.2:
#   Successfully uninstalled autogluon.timeseries-0.8.2

# %% [markdown]
# The version of Lightgbm used by AutoGluon 1.1.0 is LGBM 4.3.0, so the default install is updated below.

# %%
# !conda list lightgbm
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# lightgbm                  3.3.5           py310heca2aa9_0    conda-forge

# %%
# !pip install -qU lightgbm==4.3.0 --progress-bar off

# %% [markdown]
# # Setup

# %% [markdown]
# The necessary packages are imported below.

# %%
import pickle
import tarfile

import boto3
import pandas as pd
import sagemaker
from autogluon.tabular import TabularPredictor
from sagemaker import get_execution_role, image_uris
from sagemaker.sklearn import SKLearn
from util import DataUtil

project_bucket = '< YOUR S3 BUCKET HERE >'
train_bucket = 'train'
train_file = 'train.csv'
test_file = 'test.csv'
model_folder = 'model'
instance_type = 'ml.m5.12xlarge'
n_jobs = 48
target_variable = 'FloodProbability'

VERSION = 'v7'
TRAIN_FRACTION = 1.0

model_output = 's3://{}/{}'.format(project_bucket, model_folder)

# %% [markdown]
# Retrieve the Scikit-learn AWS docker image that will be used to train the AutoGluon model.

# %%
image_uri = image_uris.retrieve(framework='sklearn', region='us-east-1',
                    version='1.2-1', py_version='py3',
                    image_scope='training',
                    instance_type=instance_type)
image_uri
# Out:
# '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3'

# %% [markdown]
# # Train AutoGluon Models

# %% [markdown]
# Submit a training job for the AutoGluon model. The training script can be found in the `container_scripts` directory that is part of this distribution.
#
# The training script creates a AutoGluon `TabularPredictor` instance. By default, AutoGluon prototypes many algorithms including LGBM, CatBoost, XGB, random forest, KNN, Linear, etc. For this project, I limited the the models prototypes to LGBM, CatBoost, and XGB. Using the best performers, AutoGluon will also create bagged, stacker and weighted ensembles. See the `train_v7.py` script in the `container_scripts` directory for details.
#
# Setting the `use_spot_instances` to true ensures AWS EC2 spot instances were used for training.
#
# After training, SageMaker will placed the trained models in the S3 bucker you specify.
#
# Below the training job is submitted.

# %%
# %%time
aws_role = get_execution_role()
sagemaker_session = sagemaker.Session()

env = {'SAGEMAKER_REQUIREMENTS': 'requirements.txt'}

model = SKLearn(
    role=aws_role,
    sagemaker_session=sagemaker_session,
    output_path=model_output,
    code_location=model_output,
    entry_point='train_' + VERSION + '.py',
    source_dir='./container_scripts',
    env=env,
    image_uri=image_uri,
    instance_count=1,
    instance_type=instance_type,
    hyperparameters={"n_jobs": n_jobs, 
                     'training_fraction': TRAIN_FRACTION, 
                     'time_limit': 1800*5,
                     'version': VERSION},
    use_spot_instances=True,
    max_run=2000*5, 
    max_wait=2000*5,
)

model.fit()
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2024-05-28-23-41-26-071
# 2024-05-28 23:42:05 Starting - Starting the training job...
# 2024-05-28 23:42:20 Starting - Preparing the instances for training...
# 2024-05-28 23:42:51 Downloading - Downloading input data...
# 2024-05-28 23:43:27 Training - Training image download completed. Training in progress......2024-05-28 23:44:06,416 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-05-28 23:44:06,419 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-05-28 23:44:06,421 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-05-28 23:44:06,436 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-05-28 23:44:08,284 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting ray==2.10.0 (from -r requirements.txt (line 2))
#   Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting autogluon.tabular[catboost,lightgbm,xgboost] (from -r requirements.txt (line 1))
#   Downloading autogluon.tabular-1.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=7.0 in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (8.1.7)
# Collecting filelock (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting packaging (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (3.20.2)
# Collecting pyyaml (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting aiosignal (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: numpy<1.29,>=1.21 in /miniconda3/lib/python3.8/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.24.1)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in /miniconda3/lib/python3.8/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.8.0)
# Collecting pandas<2.3.0,>=2.0.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scikit-learn<1.4.1,>=1.3.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting networkx<4,>=3.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting autogluon.core==1.1.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.core-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting autogluon.features==1.1.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.features-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting xgboost<2.1,>=1.6 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting catboost<1.3,>=1.1 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading catboost-1.2.5-cp38-cp38-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting lightgbm<4.4,>=3.3 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting tqdm<5,>=4.38 (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.0 MB/s eta 0:00:00
# Collecting matplotlib (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: boto3<2,>=1.10 in /miniconda3/lib/python3.8/site-packages (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.28.57)
# Collecting autogluon.common==1.1.0 (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.common-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting psutil<6,>=5.7.3 (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.8/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (65.5.1)
# Collecting graphviz (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting plotly (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: six in /miniconda3/lib/python3.8/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.15.0)
# Collecting python-dateutil>=2.8.2 (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /miniconda3/lib/python3.8/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (2024.1)
# Collecting tzdata>=2022.1 (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: joblib>=1.1.1 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (3.5.0)
# Collecting attrs>=22.2.0 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting importlib-resources>=1.4.0 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading rpds_py-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: botocore<1.32.0,>=1.31.57 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.31.85)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (0.7.0)
# Collecting zipp>=3.1.0 (from importlib-resources>=1.4.0->jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading zipp-3.19.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading fonttools-4.52.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 3.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=6.2.0 in /miniconda3/lib/python3.8/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tenacity>=6.2.0 (from plotly->catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl (65.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 MB 39.1 MB/s eta 0:00:00
# Downloading autogluon.core-1.1.0-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 31.3 MB/s eta 0:00:00
# Downloading autogluon.features-1.1.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 9.2 MB/s eta 0:00:00
# Downloading autogluon.common-1.1.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 9.3 MB/s eta 0:00:00
# Downloading catboost-1.2.5-cp38-cp38-manylinux2014_x86_64.whl (98.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 29.3 MB/s eta 0:00:00
# Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.6 MB/s eta 0:00:00
# Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 39.1 MB/s eta 0:00:00
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.1 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 80.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 70.7 MB/s eta 0:00:00
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 7.0 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 25.0 MB/s eta 0:00:00
# Downloading autogluon.tabular-1.1.0-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 11.4 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 13.2 MB/s eta 0:00:00
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 5.4 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.6/736.6 kB 57.2 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.6 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 30.8 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.0 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.1 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 35.8 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 7.8 MB/s eta 0:00:00
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 112.7 MB/s eta 0:00:00
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 76.5 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 33.4 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.52.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 90.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 86.8 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 40.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 12.5 MB/s eta 0:00:00
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Downloading zipp-3.19.0-py3-none-any.whl (8.3 kB)
# Installing collected packages: zipp, tzdata, tqdm, tenacity, rpds-py, pyyaml, python-dateutil, pyparsing, psutil, pkgutil-resolve-name, packaging, networkx, msgpack, kiwisolver, graphviz, frozenlist, fonttools, filelock, cycler, contourpy, attrs, xgboost, scikit-learn, referencing, plotly, pandas, lightgbm, importlib-resources, aiosignal, matplotlib, jsonschema-specifications, jsonschema, catboost, ray, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.7.2
#     Uninstalling psutil-5.7.2:
#       Successfully uninstalled psutil-5.7.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.1
#     Uninstalling scikit-learn-1.2.1:
#       Successfully uninstalled scikit-learn-1.2.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-sklearn-container 2.0 requires pandas==1.1.3, but you have pandas 2.0.3 which is incompatible.
# sagemaker-sklearn-container 2.0 requires psutil==5.7.2, but you have psutil 5.9.8 which is incompatible.
# sagemaker-sklearn-container 2.0 requires python-dateutil==2.8.1, but you have python-dateutil 2.9.0.post0 which is incompatible.
# sagemaker-sklearn-container 2.0 requires scikit-learn==1.2.1, but you have scikit-learn 1.3.2 which is incompatible.
# Successfully installed aiosignal-1.3.1 attrs-23.2.0 autogluon.common-1.1.0 autogluon.core-1.1.0 autogluon.features-1.1.0 autogluon.tabular-1.1.0 catboost-1.2.5 contourpy-1.1.1 cycler-0.12.1 filelock-3.14.0 fonttools-4.52.4 frozenlist-1.4.1 graphviz-0.20.3 importlib-resources-6.4.0 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.5 lightgbm-4.3.0 matplotlib-3.7.5 msgpack-1.0.8 networkx-3.1 packaging-24.0 pandas-2.0.3 pkgutil-resolve-name-1.3.10 plotly-5.22.0 psutil-5.9.8 pyparsing-3.1.2 python-dateutil-2.9.0.post0 pyyaml-6.0.1 ray-2.10.0 referencing-0.35.1 rpds-py-0.18.1 scikit-learn-1.3.2 tenacity-8.3.0 tqdm-4.66.4 tzdata-2024.1 xgboost-2.0.3 zipp-3.19.0
# 2024-05-28 23:44:50,789 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-05-28 23:44:50,793 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-05-28 23:44:50,811 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-05-28 23:44:50,814 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-05-28 23:44:50,832 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-05-28 23:44:50,835 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-05-28 23:44:50,851 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.12xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n_jobs": 48,
#         "time_limit": 9000,
#         "training_fraction": 1.0,
#         "version": "v7"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.12xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "sagemaker-scikit-learn-2024-05-28-23-41-26-071",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://rickmartelflood/model/sagemaker-scikit-learn-2024-05-28-23-41-26-071/source/sourcedir.tar.gz",
#     "module_name": "train_v7",
#     "network_interface_name": "eth0",
#     "num_cpus": 48,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.12xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.12xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_v7.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n_jobs":48,"time_limit":9000,"training_fraction":1.0,"version":"v7"}
# SM_USER_ENTRY_POINT=train_v7.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.12xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.12xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.12xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=train_v7
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=48
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://rickmartelflood/model/sagemaker-scikit-learn-2024-05-28-23-41-26-071/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.12xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n_jobs":48,"time_limit":9000,"training_fraction":1.0,"version":"v7"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.12xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"sagemaker-scikit-learn-2024-05-28-23-41-26-071","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://rickmartelflood/model/sagemaker-scikit-learn-2024-05-28-23-41-26-071/source/sourcedir.tar.gz","module_name":"train_v7","network_interface_name":"eth0","num_cpus":48,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.12xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train_v7.py"}
# SM_USER_ARGS=["--n_jobs","48","--time_limit","9000","--training_fraction","1.0","--version","v7"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_N_JOBS=48
# SM_HP_TIME_LIMIT=9000
# SM_HP_TRAINING_FRACTION=1.0
# SM_HP_VERSION=v7
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train_v7.py --n_jobs 48 --time_limit 9000 --training_fraction 1.0 --version v7
# 2024-05-28 23:44:50,852 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-05-28 23:44:50,852 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# Arguments: Namespace(model_dir='/opt/ml/model', n_jobs=48, output_dir='/opt/ml/output', time_limit=9000, training_fraction=1.0, version='v7')
# /opt/ml/code
# Python 3.8.13
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 9000 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: /opt/ml/model/AutoGluonBuild_v7/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 1556 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 7444 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 7444s
# AutoGluon will save models to "/opt/ml/model/AutoGluonBuild_v7"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.8.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Tue Apr 9 06:57:12 UTC 2024
# CPU Count:          48
# Memory Avail:       180.94 GB / 186.60 GB (97.0%)
# Disk Space Avail:   27.48 GB / 29.36 GB (93.6%)
# ===================================================
# Train Data Rows:    1167957
# Train Data Columns: 36
# Label Column:       FloodProbability
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# #011Available Memory:                    185344.66 MB
# #011Train Data (Original)  Memory Usage: 320.79 MB (0.2% of available memory)
# #011Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# #011Stage 1 Generators:
# #011#011Fitting AsTypeFeatureGenerator...
# #011Stage 2 Generators:
# #011#011Fitting FillNaFeatureGenerator...
# #011Stage 3 Generators:
# #011#011Fitting IdentityFeatureGenerator...
# #011Stage 4 Generators:
# #011#011Fitting DropUniqueFeatureGenerator...
# #011Stage 5 Generators:
# #011#011Fitting DropDuplicatesFeatureGenerator...
# #011Types of features in original data (raw dtype, special dtypes):
# #011#011('float', []) : 11 | ['EF_mean', 'EF_std', 'EF_skew', 'EF_kurtosis', 'EF_geometric', ...]
# #011#011('int', [])   : 25 | ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', ...]
# #011Types of features in processed data (raw dtype, special dtypes):
# #011#011('float', []) : 11 | ['EF_mean', 'EF_std', 'EF_skew', 'EF_kurtosis', 'EF_geometric', ...]
# #011#011('int', [])   : 25 | ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', ...]
# #0113.3s = Fit runtime
# #01136 features in original data used to generate 36 features in processed data.
# #011Train Data (Processed) Memory Usage: 320.79 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 4.01s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# #011This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# #011To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# #011'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'colsample_bytree': 0.837979598014033, 'learning_rate': 0.007326357964510739, 'max_depth': 100, 'min_child_samples': 125, 'n_estimators': 1200, 'num_leaves': 90, 'objective': 'regression', 'subsample': 0.9321441882060605, 'subsample_freq': 6}],
# #011'CAT': [{}, {'learning_rate': 0.019893529354730797, 'depth': 7, 'l2_leaf_reg': 5, 'random_strength': 5, 'iterations': 1950, 'verbose': False}],
# #011'XGB': [{}, {'alpha': 13, 'min_child_weight': 39, 'subsample': 0.6177279393605696, 'eta': 0.23890325388859307, 'n_estimators': 1257, 'verbosity': 1}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 8 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 4958.75s of the 7439.99s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.13%)
# #011-0.0184#011 = Validation score   (-root_mean_squared_error)
# #011288.84s#011 = Training   runtime
# #011296.49s#011 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 4640.38s of the 7121.61s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.13%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01146.41s#011 = Training   runtime
# #01112.81s#011 = Validation runtime
# Fitting model: LightGBM_2_BAG_L1 ... Training model for up to 4589.76s of the 7071.0s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.13%)
#
# 2024-05-29 00:20:17 Interrupted - Training job interrupted
# 2024-05-29 00:21:04 Starting - Starting the training job
# 2024-05-29 00:21:42 Starting - Preparing the instances for training
# 2024-05-29 00:22:10 Downloading - Downloading input data
# 2024-05-29 00:22:20 Downloading - Downloading the training image
# 2024-05-29 00:22:46 Training - Training image download completed. Training in progress.2024-05-29 00:23:25,434 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-05-29 00:23:25,437 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-05-29 00:23:25,440 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-05-29 00:23:25,454 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-05-29 00:23:27,433 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting ray==2.10.0 (from -r requirements.txt (line 2))
#   Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting autogluon.tabular[catboost,lightgbm,xgboost] (from -r requirements.txt (line 1))
#   Downloading autogluon.tabular-1.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=7.0 in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (8.1.7)
# Collecting filelock (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting packaging (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (3.20.2)
# Collecting pyyaml (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting aiosignal (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray==2.10.0->-r requirements.txt (line 2))
#   Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /miniconda3/lib/python3.8/site-packages (from ray==2.10.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: numpy<1.29,>=1.21 in /miniconda3/lib/python3.8/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.24.1)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in /miniconda3/lib/python3.8/site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.8.0)
# Collecting pandas<2.3.0,>=2.0.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scikit-learn<1.4.1,>=1.3.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting networkx<4,>=3.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting autogluon.core==1.1.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.core-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting autogluon.features==1.1.0 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.features-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting catboost<1.3,>=1.1 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading catboost-1.2.5-cp38-cp38-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting xgboost<2.1,>=1.6 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting lightgbm<4.4,>=3.3 (from autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting tqdm<5,>=4.38 (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 10.2 MB/s eta 0:00:00
# Collecting matplotlib (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: boto3<2,>=1.10 in /miniconda3/lib/python3.8/site-packages (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.28.57)
# Collecting autogluon.common==1.1.0 (from autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading autogluon.common-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting psutil<6,>=5.7.3 (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.8/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (65.5.1)
# Collecting graphviz (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting plotly (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: six in /miniconda3/lib/python3.8/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.15.0)
# Collecting python-dateutil>=2.8.2 (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /miniconda3/lib/python3.8/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (2024.1)
# Collecting tzdata>=2022.1 (from pandas<2.3.0,>=2.0.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: joblib>=1.1.1 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (3.5.0)
# Collecting attrs>=22.2.0 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting importlib-resources>=1.4.0 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading rpds_py-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.8/site-packages (from requests->ray==2.10.0->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: botocore<1.32.0,>=1.31.57 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.31.85)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /miniconda3/lib/python3.8/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (0.7.0)
# Collecting zipp>=3.1.0 (from importlib-resources>=1.4.0->jsonschema->ray==2.10.0->-r requirements.txt (line 2))
#   Downloading zipp-3.19.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading fonttools-4.52.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 23.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=6.2.0 in /miniconda3/lib/python3.8/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1)) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->autogluon.core==1.1.0->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tenacity>=6.2.0 (from plotly->catboost<1.3,>=1.1->autogluon.tabular[catboost,lightgbm,xgboost]->-r requirements.txt (line 1))
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl (65.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 MB 28.0 MB/s eta 0:00:00
# Downloading autogluon.core-1.1.0-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.5 MB/s eta 0:00:00
# Downloading autogluon.features-1.1.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 13.9 MB/s eta 0:00:00
# Downloading autogluon.common-1.1.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 13.8 MB/s eta 0:00:00
# Downloading catboost-1.2.5-cp38-cp38-manylinux2014_x86_64.whl (98.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 29.1 MB/s eta 0:00:00
# Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 114.4 MB/s eta 0:00:00
# Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 49.7 MB/s eta 0:00:00
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 112.1 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 107.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 106.3 MB/s eta 0:00:00
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 7.0 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 46.2 MB/s eta 0:00:00
# Downloading autogluon.tabular-1.1.0-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 44.0 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.0 MB/s eta 0:00:00
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 9.7 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.6/736.6 kB 69.1 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 12.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 39.4 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 80.5 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 14.8 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 51.2 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 10.1 MB/s eta 0:00:00
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 117.8 MB/s eta 0:00:00
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 111.8 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 7.4 MB/s eta 0:00:00
# ...
# SM_USER_ARGS=["--n_jobs","48","--time_limit","9000","--training_fraction","1.0","--version","v7"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_N_JOBS=48
# SM_HP_TIME_LIMIT=9000
# SM_HP_TRAINING_FRACTION=1.0
# SM_HP_VERSION=v7
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train_v7.py --n_jobs 48 --time_limit 9000 --training_fraction 1.0 --version v7
# 2024-05-29 00:24:08,333 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-05-29 00:24:08,333 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# Arguments: Namespace(model_dir='/opt/ml/model', n_jobs=48, output_dir='/opt/ml/output', time_limit=9000, training_fraction=1.0, version='v7')
# /opt/ml/code
# Python 3.8.13
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 9000 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: /opt/ml/model/AutoGluonBuild_v7/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 1634 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 7366 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 7366s
# AutoGluon will save models to "/opt/ml/model/AutoGluonBuild_v7"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.8.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Tue Apr 9 06:57:12 UTC 2024
# CPU Count:          48
# Memory Avail:       179.23 GB / 184.63 GB (97.1%)
# Disk Space Avail:   27.48 GB / 29.36 GB (93.6%)
# ===================================================
# Train Data Rows:    1167957
# Train Data Columns: 36
# Label Column:       FloodProbability
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# #011Available Memory:                    183602.66 MB
# #011Train Data (Original)  Memory Usage: 320.79 MB (0.2% of available memory)
# #011Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# #011Stage 1 Generators:
# #011#011Fitting AsTypeFeatureGenerator...
# #011Stage 2 Generators:
# #011#011Fitting FillNaFeatureGenerator...
# #011Stage 3 Generators:
# #011#011Fitting IdentityFeatureGenerator...
# #011Stage 4 Generators:
# #011#011Fitting DropUniqueFeatureGenerator...
# #011Stage 5 Generators:
# #011#011Fitting DropDuplicatesFeatureGenerator...
# #011Types of features in original data (raw dtype, special dtypes):
# #011#011('float', []) : 11 | ['EF_mean', 'EF_std', 'EF_skew', 'EF_kurtosis', 'EF_geometric', ...]
# #011#011('int', [])   : 25 | ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', ...]
# #011Types of features in processed data (raw dtype, special dtypes):
# #011#011('float', []) : 11 | ['EF_mean', 'EF_std', 'EF_skew', 'EF_kurtosis', 'EF_geometric', ...]
# #011#011('int', [])   : 25 | ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', ...]
# #0113.5s = Fit runtime
# #01136 features in original data used to generate 36 features in processed data.
# #011Train Data (Processed) Memory Usage: 320.79 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 4.27s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# #011This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# #011To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# #011'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'colsample_bytree': 0.837979598014033, 'learning_rate': 0.007326357964510739, 'max_depth': 100, 'min_child_samples': 125, 'n_estimators': 1200, 'num_leaves': 90, 'objective': 'regression', 'subsample': 0.9321441882060605, 'subsample_freq': 6}],
# #011'CAT': [{}, {'learning_rate': 0.019893529354730797, 'depth': 7, 'l2_leaf_reg': 5, 'random_strength': 5, 'iterations': 1950, 'verbose': False}],
# #011'XGB': [{}, {'alpha': 13, 'min_child_weight': 39, 'subsample': 0.6177279393605696, 'eta': 0.23890325388859307, 'n_estimators': 1257, 'verbosity': 1}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 8 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 4906.59s of the 7361.73s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.14%)
# #011-0.0184#011 = Validation score   (-root_mean_squared_error)
# #011289.11s#011 = Training   runtime
# #011147.44s#011 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 4598.42s of the 7053.55s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.14%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01142.8s#011 = Training   runtime
# #01110.23s#011 = Validation runtime
# Fitting model: LightGBM_2_BAG_L1 ... Training model for up to 4551.68s of the 7006.81s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.14%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011120.92s#011 = Training   runtime
# #01163.86s#011 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4421.91s of the 6877.04s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.14%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011329.64s#011 = Training   runtime
# #0110.32s#011 = Validation runtime
# Fitting model: CatBoost_2_BAG_L1 ... Training model for up to 4089.93s of the 6545.07s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.15%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011178.63s#011 = Training   runtime
# #0110.32s#011 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3908.96s of the 6364.09s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.50%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01127.07s#011 = Training   runtime
# #0114.89s#011 = Validation runtime
# Fitting model: XGBoost_2_BAG_L1 ... Training model for up to 3879.07s of the 6334.2s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.50%)
# #011-0.0184#011 = Validation score   (-root_mean_squared_error)
# #011111.85s#011 = Training   runtime
# #01122.73s#011 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3762.57s of the 6217.71s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.15%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01133.93s#011 = Training   runtime
# #0114.92s#011 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 490.66s of the 6180.75s of remaining time.
# #011Ensemble Weights: {'LightGBM_2_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.25, 'LightGBMLarge_BAG_L1': 0.25}
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #0111.52s#011 = Training   runtime
# #0110.02s#011 = Validation runtime
# Fitting 8 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 6179.16s of the 6178.92s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.26%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01180.05s#011 = Training   runtime
# #01128.82s#011 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 6092.61s of the 6092.38s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.26%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01117.24s#011 = Training   runtime
# #0111.73s#011 = Validation runtime
# Fitting model: LightGBM_2_BAG_L2 ... Training model for up to 6072.3s of the 6072.07s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.27%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011121.86s#011 = Training   runtime
# #01128.36s#011 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5944.11s of the 5943.88s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.27%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011116.2s#011 = Training   runtime
# #0110.23s#011 = Validation runtime
# Fitting model: CatBoost_2_BAG_L2 ... Training model for up to 5825.0s of the 5824.76s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.27%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #011197.49s#011 = Training   runtime
# #0110.34s#011 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 5624.55s of the 5624.32s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.66%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01118.88s#011 = Training   runtime
# #0114.15s#011 = Validation runtime
# Fitting model: XGBoost_2_BAG_L2 ... Training model for up to 5602.29s of the 5602.05s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.66%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01123.28s#011 = Training   runtime
# #0114.89s#011 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 5575.63s of the 5575.4s of remaining time.
# #011Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=6, gpus=0, memory=1.27%)
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #01130.29s#011 = Training   runtime
# #0113.4s#011 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 617.92s of the 5541.6s of remaining time.
# #011Ensemble Weights: {'LightGBM_2_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.25, 'XGBoost_BAG_L2': 0.25}
# #011-0.0183#011 = Validation score   (-root_mean_squared_error)
# #0112.23s#011 = Training   runtime
# #0110.02s#011 = Validation runtime
# AutoGluon training complete, total runtime = 1827.22s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/opt/ml/model/AutoGluonBuild_v7")
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# #011Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# #011This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# #011To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# #01142.86s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# #0116.96s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_2_BAG_L1_FULL ...
# Found `n_estimators` in params. Will use it instead of argument
# #01122.27s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# #01149.87s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_2_BAG_L1_FULL ...
# #01139.39s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# #0115.96s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_2_BAG_L1_FULL ...
# #01119.59s#011 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# #0116.83s#011 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# #011Ensemble Weights: {'LightGBM_2_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.25, 'LightGBMLarge_BAG_L1': 0.25}
# #0111.52s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# #01113.33s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# #0113.35s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_2_BAG_L2_FULL ...
# Found `n_estimators` in params. Will use it instead of argument
# #01124.65s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# #01118.2s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_2_BAG_L2_FULL ...
# #01141.24s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# #0116.56s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_2_BAG_L2_FULL ...
# #0116.78s#011 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# #0115.89s#011 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# #011Ensemble Weights: {'LightGBM_2_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.25, 'XGBoost_BAG_L2': 0.25}
# #0112.23s#011 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 326.73s ... Best model: "WeightedEnsemble_L3_FULL"
# 2024-05-29 01:28:33,307 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-05-29 01:29:13 Uploading - Uploading generated training model
# 2024-05-29 01:29:13 Completed - Training job completed
# Training seconds: 4023
# Billable seconds: 1678
# Managed Spot Training savings: 58.3%
# CPU times: user 52.9 s, sys: 1.45 s, total: 54.4 s
# Wall time: 1h 48min 11s

# %% [markdown]
# Trained has finished. As you can see, it took almost 2 hours to train all the modlels.

# %% [markdown]
# # Retrieve and Load Trained AutoGluon Model

# %% [markdown]
# Below the trained model is retrieved from S3, loaded, and the model leader board displayed.

# %% [markdown]
# ## Get archive from S3.

# %%
s3_client = boto3.client('s3')
s3_resource = boto3.resource('s3')

contents = s3_client.list_objects_v2(Bucket=project_bucket, Prefix=model_folder).get('Contents', [])
last_sklearn_model = None
for content in contents:
    if 'sagemaker-scikit-learn' in content['Key'] \
      and 'model.tar.gz' in content['Key']:
      last_sklearn_model = content['Key']

print(last_sklearn_model)
s3_resource.meta.client.download_file(project_bucket,
                                      last_sklearn_model,
                                      './model.tar.gz')
t = tarfile.open('./model.tar.gz', 'r:gz')
t.extractall()
# Out:
# model/sagemaker-scikit-learn-2024-05-28-23-41-26-071/output/model.tar.gz

# %% [markdown]
# ## Load model

# %%
predictor = TabularPredictor.load('./AutoGluonBuild_' + VERSION, check_packages=False,
                                  require_py_version_match=False)
# Out:
# Found 1 mismatches between original and current metadata:
# 	WARNING: AutoGluon Python version mismatch (original=3.8, current=3.10)

# %% [markdown]
# ## View AutoGluon Model Leader Board

# %% [markdown]
# The best model was a weighted ensemble. In the training script, the best model was retrained on all the data and is the default model called when make predictions.

# %%
print(predictor.model_best)
print(predictor.model_names())
# Out:
# WeightedEnsemble_L3_FULL
# ['LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'LightGBM_2_BAG_L1', 'CatBoost_BAG_L1', 'CatBoost_2_BAG_L1', 'XGBoost_BAG_L1', 'XGBoost_2_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'LightGBM_2_BAG_L2', 'CatBoost_BAG_L2', 'CatBoost_2_BAG_L2', 'XGBoost_BAG_L2', 'XGBoost_2_BAG_L2', 'LightGBMLarge_BAG_L2', 'WeightedEnsemble_L3', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'LightGBM_2_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'CatBoost_2_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'XGBoost_2_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'WeightedEnsemble_L2_FULL', 'LightGBMXT_BAG_L2_FULL', 'LightGBM_BAG_L2_FULL', 'LightGBM_2_BAG_L2_FULL', 'CatBoost_BAG_L2_FULL', 'CatBoost_2_BAG_L2_FULL', 'XGBoost_BAG_L2_FULL', 'XGBoost_2_BAG_L2_FULL', 'LightGBMLarge_BAG_L2_FULL', 'WeightedEnsemble_L3_FULL']

# %%
predictor.leaderboard()
# Out:
#                         model  score_val              eval_metric  \
# 0         WeightedEnsemble_L3  -0.018298  root_mean_squared_error
# 1         WeightedEnsemble_L2  -0.018299  root_mean_squared_error
# 2           LightGBM_2_BAG_L1  -0.018302  root_mean_squared_error
# 3             LightGBM_BAG_L2  -0.018303  root_mean_squared_error
# 4           LightGBM_2_BAG_L2  -0.018303  root_mean_squared_error
# 5              XGBoost_BAG_L2  -0.018304  root_mean_squared_error
# 6        LightGBMLarge_BAG_L1  -0.018305  root_mean_squared_error
# 7        LightGBMLarge_BAG_L2  -0.018305  root_mean_squared_error
# 8           CatBoost_2_BAG_L2  -0.018310  root_mean_squared_error
# 9             CatBoost_BAG_L1  -0.018312  root_mean_squared_error
# 10            CatBoost_BAG_L2  -0.018312  root_mean_squared_error
# 11            LightGBM_BAG_L1  -0.018318  root_mean_squared_error
# 12             XGBoost_BAG_L1  -0.018318  root_mean_squared_error
# 13          LightGBMXT_BAG_L2  -0.018326  root_mean_squared_error
# 14          CatBoost_2_BAG_L1  -0.018327  root_mean_squared_error
# 15           XGBoost_2_BAG_L2  -0.018341  root_mean_squared_error
# 16          LightGBMXT_BAG_L1  -0.018352  root_mean_squared_error
# 17           XGBoost_2_BAG_L1  -0.018395  root_mean_squared_error
# 18        XGBoost_BAG_L2_FULL        NaN  root_mean_squared_error
# 19        XGBoost_BAG_L1_FULL        NaN  root_mean_squared_error
# 20      XGBoost_2_BAG_L2_FULL        NaN  root_mean_squared_error
# 21      XGBoost_2_BAG_L1_FULL        NaN  root_mean_squared_error
# 22   WeightedEnsemble_L3_FULL        NaN  root_mean_squared_error
# 23   WeightedEnsemble_L2_FULL        NaN  root_mean_squared_error
# 24       LightGBM_BAG_L2_FULL        NaN  root_mean_squared_error
# 25       LightGBM_BAG_L1_FULL        NaN  root_mean_squared_error
# 26     LightGBM_2_BAG_L2_FULL        NaN  root_mean_squared_error
# 27     LightGBM_2_BAG_L1_FULL        NaN  root_mean_squared_error
# 28     LightGBMXT_BAG_L2_FULL        NaN  root_mean_squared_error
# 29     LightGBMXT_BAG_L1_FULL        NaN  root_mean_squared_error
# 30  LightGBMLarge_BAG_L2_FULL        NaN  root_mean_squared_error
# 31  LightGBMLarge_BAG_L1_FULL        NaN  root_mean_squared_error
# 32       CatBoost_BAG_L2_FULL        NaN  root_mean_squared_error
# 33       CatBoost_BAG_L1_FULL        NaN  root_mean_squared_error
# 34     CatBoost_2_BAG_L2_FULL        NaN  root_mean_squared_error
# 35     CatBoost_2_BAG_L1_FULL        NaN  root_mean_squared_error
#
#     pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0      258.863275  1155.066262                0.016854           2.228569
# 1       69.108697   486.015297                0.016777           1.516208
# 2       63.855961   120.923009               63.855961         120.923009
# 3      256.432776  1151.194993                1.734181          17.237268
# 4      283.059128  1255.822067               28.360533         121.864342
# 5      258.846421  1152.837693                4.147826          18.879969
# 6        4.919061    33.932035                4.919061          33.932035
# 7      258.101056  1164.244439                3.402462          30.286715
# 8      255.041685  1331.452339                0.343091         197.494615
# 9        0.316898   329.644045                0.316898         329.644045
# 10     254.925656  1250.155735                0.227061         116.198011
# 11      10.229668    42.804555               10.229668          42.804555
# 12       4.886454    27.069255                4.886454          27.069255
# 13     283.515589  1214.011457               28.816995          80.053732
# 14       0.315053   178.630243                0.315053         178.630243
# 15     259.586198  1157.234126                4.887604          23.276401
# 16     147.441484   289.107531              147.441484         289.107531
# 17      22.734016   111.847052               22.734016         111.847052
# 18            NaN   200.278528                     NaN           6.558067
# 19            NaN     5.956487                     NaN           5.956487
# 20            NaN   200.501502                     NaN           6.781041
# 21            NaN    19.585535                     NaN          19.585535
# 22            NaN   202.507097                     NaN           2.228569
# 23            NaN    80.485221                     NaN           1.516208
# 24            NaN   197.074990                     NaN           3.354529
# 25            NaN     6.957663                     NaN           6.957663
# 26            NaN   218.369319                     NaN          24.648858
# 27            NaN    22.268695                     NaN          22.268695
# 28            NaN   207.054620                     NaN          13.334159
# 29            NaN    42.860676                     NaN          42.860676
# 30            NaN   199.615307                     NaN           5.894847
# 31            NaN     6.833948                     NaN           6.833948
# 32            NaN   211.916675                     NaN          18.196214
# 33            NaN    49.866370                     NaN          49.866370
# 34            NaN   234.964779                     NaN          41.244318
# 35            NaN    39.391087                     NaN          39.391087
#
#     stack_level  can_infer  fit_order
# 0             3       True         18
# 1             2       True          9
# 2             1       True          3
# 3             2       True         11
# 4             2       True         12
# 5             2       True         15
# 6             1       True          8
# 7             2       True         17
# 8             2       True         14
# 9             1       True          4
# 10            2       True         13
# 11            1       True          2
# 12            1       True          6
# 13            2       True         10
# 14            1       True          5
# 15            2       True         16
# 16            1       True          1
# 17            1       True          7
# 18            2       True         33
# 19            1       True         24
# 20            2       True         34
# 21            1       True         25
# 22            3       True         36
# 23            2       True         27
# 24            2       True         29
# 25            1       True         20
# 26            2       True         30
# 27            1       True         21
# 28            2       True         28
# 29            1       True         19
# 30            2       True         35
# 31            1       True         26
# 32            2       True         31
# 33            1       True         22
# 34            2       True         32
# 35            1       True         23

# %% [markdown]
# # Create Kaggle Submission

# %% [markdown]
# Below the Kaggle submission data is loaded and and predictions of flood probability made.

# %%
util = DataUtil(project_bucket,
                train_bucket,
                train_file,
                target_variable,
                test_file)
ds = util.get_data_sagemaker()
train = ds['train']
if TRAIN_FRACTION < 1.0:
    train = train.sample(frac=TRAIN_FRACTION)
trainX = train.copy()
trainy = trainX.pop('FloodProbability')
testX = ds['test']
if TRAIN_FRACTION < 1.0:
    testX = testX.sample(frac=TRAIN_FRACTION)

# %% [markdown]
# Lets take a look as some of the test data.

# %%
testX.describe()
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# count     745305.000000       745305.000000    745305.000000  745305.000000
# mean           4.915610            4.930288         4.960027       4.946084
# std            2.056295            2.094117         2.071722       2.052602
# min            0.000000            0.000000         0.000000       0.000000
# 25%            3.000000            3.000000         4.000000       4.000000
# 50%            5.000000            5.000000         5.000000       5.000000
# 75%            6.000000            6.000000         6.000000       6.000000
# max           16.000000           17.000000        16.000000      17.000000
#
#         Urbanization  ClimateChange    DamsQuality      Siltation  \
# count  745305.000000  745305.000000  745305.000000  745305.000000
# mean        4.938424       4.933524       4.958468       4.927651
# std         2.081816       2.059243       2.089312       2.068110
# min         0.000000       0.000000       0.000000       0.000000
# 25%         3.000000       3.000000       4.000000       3.000000
# 50%         5.000000       5.000000       5.000000       5.000000
# 75%         6.000000       6.000000       6.000000       6.000000
# max        17.000000      17.000000      16.000000      16.000000
#
#        AgriculturalPractices  Encroachments  ...  PopulationScore  \
# count          745305.000000   745305.00000  ...    745305.000000
# mean                4.945308        4.95062  ...         4.926957
# std                 2.073404        2.08175  ...         2.073692
# min                 0.000000        0.00000  ...         0.000000
# 25%                 3.000000        4.00000  ...         3.000000
# 50%                 5.000000        5.00000  ...         5.000000
# 75%                 6.000000        6.00000  ...         6.000000
# max                16.000000       17.00000  ...        19.000000
#
#          WetlandLoss  InadequatePlanning  PoliticalFactors     autoFE_f_0  \
# count  745305.000000       745305.000000     745305.000000  745305.000000
# mean        4.948424            4.940204          4.943918       9.904552
# std         2.065891            2.079128          2.087387       2.913573
# min         0.000000            0.000000          0.000000       0.000000
# 25%         4.000000            3.000000          3.000000       8.000000
# 50%         5.000000            5.000000          5.000000      10.000000
# 75%         6.000000            6.000000          6.000000      12.000000
# max        22.000000           16.000000         16.000000      27.000000
#
#           autoFE_f_1     autoFE_f_2     autoFE_f_3     autoFE_f_4  \
# count  745305.000000  745305.000000  745305.000000  745305.000000
# mean       24.408708       9.842568       0.500085      24.229858
# std        15.049644       2.906872       0.285499      14.924683
# min         0.000000       0.000000       0.002194       0.000000
# 25%        14.000000       8.000000       0.189003      14.000000
# 50%        21.000000      10.000000       0.541247      21.000000
# 75%        32.000000      12.000000       0.712094      32.000000
# max       180.000000      27.000000       1.000000     156.000000
#
#           autoFE_f_5
# count  745305.000000
# mean        9.853714
# std         2.912735
# min         0.000000
# 25%         8.000000
# 50%        10.000000
# 75%        12.000000
# max        26.000000
#
# [8 rows x 26 columns]

# %%
testX.head()
# Out:
#          MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# id
# 1117957                 4                   6                3              5
# 1117958                 4                   4                2              9
# 1117959                 1                   3                6              5
# 1117960                 2                   4                4              6
# 1117961                 6                   3                2              4
#
#          Urbanization  ClimateChange  DamsQuality  Siltation  \
# id
# 1117957             6              7            8          7
# 1117958             5              5            4          7
# 1117959             7              2            4          6
# 1117960             4              5            4          3
# 1117961             6              4            5          5
#
#          AgriculturalPractices  Encroachments  ...  PopulationScore  \
# id                                             ...
# 1117957                      8              4  ...                6
# 1117958                      5              4  ...                7
# 1117959                      4              2  ...                3
# 1117960                      4              4  ...                4
# 1117961                      3              7  ...                8
#
#          WetlandLoss  InadequatePlanning  PoliticalFactors  autoFE_f_0  \
# id
# 1117957            4                   4                 5        13.0
# 1117958            4                   4                 3        13.0
# 1117959            6                   8                 3         9.0
# 1117960            2                   4                 4        10.0
# 1117961            4                   5                 5         9.0
#
#          autoFE_f_1  autoFE_f_2  autoFE_f_3  autoFE_f_4  autoFE_f_5
# id
# 1117957        18.0        10.0    0.910823        15.0        10.0
# 1117958         8.0        11.0    0.075057         4.0         8.0
# 1117959        18.0         4.0    0.829648        10.0         8.0
# 1117960        16.0         6.0    0.831339        36.0         9.0
# 1117961         6.0        14.0    0.347882        36.0        11.0
#
# [5 rows x 26 columns]

# %% [markdown]
# The code below creates the Kaggle submission that can later be submitted to the competition.

# %%
# %%time
print('Get predictions from test data...')
pred = predictor.predict(testX)
df_results = pd.DataFrame(data={target_variable:pred}, index=testX.index)
df_results.index.name = "id"
df_results.to_csv("flood_ag_v7.csv")
print('Done.')
# Out:
# Get predictions from test data...
# Done.
# CPU times: user 15min 51s, sys: 2.54 s, total: 15min 53s
# Wall time: 2min 14s

# %% [markdown]
# Lets do a sanity check on the file.

# %%
flood_submit = pd.read_csv('./flood_ag_v7.csv')

# %%
flood_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745305 entries, 0 to 745304
# Data columns (total 2 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                745305 non-null  int64
#  1   FloodProbability  745305 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 11.4 MB

# %%
flood_submit.head()
# Out:
#         id  FloodProbability
# 0  1117957          0.577464
# 1  1117958          0.454134
# 2  1117959          0.449175
# 3  1117960          0.470078
# 4  1117961          0.468185

# %% [markdown]
# This looks correct.
